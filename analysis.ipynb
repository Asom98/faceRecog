# %%
import pandas as pd

file_path = r'C:/Users/kasse/Documents/faceRecog/archive/data.csv'
df = pd.read_csv(file_path)

# Display the first few rows of the dataset
print("First few records:")
display(df.head())

# General information about the dataset
print("\nDataset Info:")
df.info()

# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Basic statistical summary of the dataset
print("\nStatistical Summary:")
print(df.describe())

# Count the number of unique classes (emotion labels)
print("\nUnique Labels:")
print(df['label'].value_counts())

# Shape of the dataset
print(f"\nNumber of Records: {df.shape[0]}")
print(f"Number of Attributes: {df.shape[1]}")
# Out:
# First few records:
#    Unnamed: 0                                               path     label
# 0           0  Surprise/1bd930d6a1c717c11be33db74823f661cb53f...  Surprise
# 1           1       Surprise/cropped_emotions.100096~12fffff.png  Surprise
# 2           2  Surprise/0df0e470e33093f5b72a8197fa209d684032c...  Surprise
# 3           3       Surprise/cropped_emotions.260779~12fffff.png  Surprise
# 4           4       Surprise/cropped_emotions.263616~12fffff.png  Surprise
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15453 entries, 0 to 15452
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  15453 non-null  int64
#  1   path        15453 non-null  object
#  2   label       15453 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 362.3+ KB
#
# Missing Values:
# Unnamed: 0    0
# path          0
# label         0
# dtype: int64
#
# Statistical Summary:
#         Unnamed: 0
# count  15453.00000
# mean    7726.00000
# std     4461.04119
# min        0.00000
# 25%     3863.00000
# 50%     7726.00000
# 75%    11589.00000
# max    15452.00000
#
# Unique Labels:
# label
# Neutral     4027
# Sad         3934
# Happy       3740
# Angry       1313
# Surprise    1234
# Ahegao      1205
# Name: count, dtype: int64
#
# Number of Records: 15453
# Number of Attributes: 3
